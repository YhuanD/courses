# %% [markdown]
# ## <Center><font color=red><b>考试题参考答案</b></font></Center>

# %% [markdown]
# ____

# %% [markdown]
# ### 简答题(4分/题 共100分)

# %% [markdown]
# ### 1.简述线性分类器的原理.

# %% [markdown]
# 线性分类器就是将每个被分类样本与权重矩阵进行对比,找到相似度最大的权重行,给出相应的标签.

# %% [markdown]
# ### 2.物体检测问题概述

# %% [markdown]
# * 用框去标出物体部分，并且给出该物体的类别或属于某类别的概率

# %% [markdown]
# ### 3.计算机视觉中，有哪几种基本任务？

# %% [markdown]
# * 图像分类
# * 图像定位
# * 物体检测
# * 物体分割

# %% [markdown]
# ### 4.常见物体检测算法列举

# %% [markdown]
# * Deformable Parts Model
# * RCNN
# * Fast-RCNN
# * Faster-RCNN
# * RFCN
# * Mask-RCNN

# %% [markdown]
# ### 5.针对如下图片,我们需要调节哪些参数?为什么?![%E8%B0%83%E5%8F%82%E9%97%AE%E9%A2%98.png](attachment:%E8%B0%83%E5%8F%82%E9%97%AE%E9%A2%98.png)

# %% [markdown]
# * 上面的曲线:调节学习率,先大后小.因为图像中曲线前期太平缓,所以要调大,后期跳动太大,需要调小!
# * 下面的曲线:欠拟合,更换表征能力的模型,增加数据量.

# %% [markdown]
# ### 6.写出神经网络中常见的激励函数(至少三个).

# %% [markdown]
# * Sigmoid
# * Tanh
# * ReLU
# * Leaky RelU

# %% [markdown]
# ### 7.请问图示中卷积模板功能?![%E8%BE%B9%E7%BC%98%E6%A3%80%E6%B5%8B.png](attachment:%E8%BE%B9%E7%BC%98%E6%A3%80%E6%B5%8B.png)

# %% [markdown]
# 边缘检测

# %% [markdown]
# ### 8、计算题(提示:参数共享)

# %% [markdown]
# * Example1: 200\*200 image(灰度图), 40K hidden units  有多少个参数?
# * Example2: 200\*200 image(灰度图), 40K hidden units, Filter size: 10\*10 有多少个参数?
# * Example3: 200\*200 image(灰度图), 100 Filter, Filter size:10\*10  有多少参数?
# * Example4: 图像尺寸为[32\*32\*3], 卷积窗口大小为5\*5, 卷积模板个数为1, 有多少参数?
# * Example5: 图像尺寸为[16\*16\*20], 卷积窗口大小为3\*3, 卷积模板个数为10, 有多少参数?

# %% [markdown]
# * Example1: 40000 \* 40000 = 16 0000 0000个
# * Example2: 40000 \* 10 \* 10 = 4 00 0000个
# * Example3: 100 \* 10 \* 10 = 1 00 00个
# * Example4: 5 \* 5 \* 3 = 75个
# * Example5: 3 \* 3 \* 20 \* 10 = 1800个

# %% [markdown]
# ### 9.计算下图pool池化层结果(取最大值)![pool%E6%B1%A0%E5%8C%96%E5%B1%82.png](attachment:pool%E6%B1%A0%E5%8C%96%E5%B1%82.png)

# %% [markdown]
# 6 8
# 3 4

# %% [markdown]
# ### 10.什么是感受野?

# %% [markdown]
# 某一层特征图中的一个cell,对应到原始输入图片相应的大小区域.

# %% [markdown]
# ### 11.简述Encode和Decode思想

# %% [markdown]
# * 将一个input信息编码到一个压缩空间中
# * 将一个压缩空间向量解码到一个原始空间中

# %% [markdown]
# ### 12.什么是NMS（Non-maximum suppression 非极大值抑制）?

# %% [markdown]
# * NMS是一种Post-Procession（后处理）方式，跟算法无关的方式。
# * NMS应用在所有物体检测的方法里。
# * NMS物体检测的指标里，不允许出现多个重复的检测。
# * NMS把所有检测结果按照分值(conf. score)从高到底排序,保留最高分数的 box,删除其余值。

# %% [markdown]
# ### 13.什么是Hard Mining？

# %% [markdown]
# > 在容易混淆的类别中加入相似负样本，再次训练分类器，使得分类器在之前效果不好的地方，都能有一个好的分类效果。

# %% [markdown]
# ### 14.在一个CNN网络中，计算整个数据集是不现实的，通常使用什么方法估计呢？

# %% [markdown]
# * mini-batch
# > 在mini batch下的梯度下降中做的事情其实跟full batch一样，只不过我们训练的数据不再是所有的样本，而是一个个的子集。

# %% [markdown]
# ### 15.以下哪个参数是learning rate(学习速率)?Weight decay(权值衰减量)?momentum(动量)?
# $$ L(w) = \frac{1}{N}\sum_{i=0}^{N}f_w(X^{(i)})+\lambda r(W)$$
# $$ V_{i+1} = \mu V_{t} - \alpha \nabla L(W_{i} )$$
# $$ W_{i+1} = W_{i} + V_{i+1} $$

# %% [markdown]
# * $\alpha$ : learning rate
# * $\mu$ : momentum (调节跨度)
# * $\lambda$ : weight decay

# %% [markdown]
# ### 16.课上讲的深度学习三要素是哪三个(加入自己理解回答)?

# %% [markdown]
# * 首先关注**模型**:用了什么结构?
# * 在什么**数据集**上做的?实验效果如何?
# * **算法**
#     * 训练过程: loss, sampling, 梯度
#     * 测试过程: multi-scale, NMS

# %% [markdown]
# ### 17.传统方法selective search是如何生成目标框的?

# %% [markdown]
# > selective search 是一中自下而上(bottom-up segmentation)方法:
# 它是基于SLIC算法,先将图像分割成很多小的区域(superpixe超像素),然后根据小区域之间的相似程度来融合.最后结合各个尺度上的结果,产生很多region proposals(区域建议).

# %% [markdown]
# ### 18.Faster-RCNN中2k scores的2和4k coordinates的4分别是什么意思?

# %% [markdown]
# * 2k scores中的2表示feature map上的特征点对应某个模板(anchor)来说,是作为前景和背景的两个概率值.
# * 4k coordinates中的4表示feature map上的特征点对应某个模板(anchor)来说,其框的左上角(x,y)值与右下角(x,y)值的个数和

# %% [markdown]
# ### 19.写出Faster-RCNN的损失函数公式

# %% [markdown]
# $$L({p_i},{t_i}) = \frac{1}{N_{cls}}\sum_{i} L_{cls}(p_i,p_i^*) + \lambda \frac{1}{N_{cls}}\sum_{i}p_i^*L_{reg}(t_i,t_i^*)$$
# > 延伸
# $p_i$是第i个anchor是否含有物体的概率,范围0-1. $p_i^*$是真值
# $t_i$是第i个anchor的预测位置= [$x_1,y_1,x_2,y_2$]
# $L_{reg}$仅将分类正确的项做回归
# $L_{cls}$: cross-entripy loss

# %% [markdown]
# ### 20.写出Faster-RCNN的损失函数中分类损失 $L_{cls}(p_i,p_i^*)$的具体形式

# %% [markdown]
# * $$L_{c l s}\left(p_{i}, p_{i}^{*}\right)=-\log \left[p_{i}^{*} p_{i}+\left(1-p_{i}^{*}\right)\left(1-p_{i}\right)\right]$$

# %% [markdown]
# ### 21.写出目标检测的评价指标中Precision和Recall公式

# %% [markdown]
# * $$Precision = \cfrac{TP}{TP + FP}$$
# * $$Recall = \cfrac{TP}{TP  + FN}$$

# %% [markdown]
# ### 22.FCN与CNN最大的区别？

# %% [markdown]
# * 先把图进行一次CNN,对每个特征框仅在原图的特征地图上进行提取
# * 加入池化(Rol polling),固定输出大小

# %% [markdown]
# ### 23.Fully-convolutional network (FCN)的流程

# %% [markdown]
# > 回答1
# * 训练问题:端到端学习
# * 连接层问题:全连接改为全卷积,支持可变输入
# * 特征图变小问题:利用反卷积向上放大特征 图
# * 特征融合问题:利用skip connection融合多层特征提高上采 样精细度
#
# > 回答2
# * input
# * Down-sampling
# * up-sampling
# * predictions

# %% [markdown]
# ### 24.简述RCNN(Region CNN)流程.

# %% [markdown]
# * Step1: 通过传统方式对物体进行识别和框选(NMS)
# * Step2: 将已框选的物体进行提取拉伸
# * Step3: 对已提取的物体图进行卷积操作,生成特征向量(这是RCNN的瓶颈:对每个框都要过一遍ConvNet,计算量级太大)
# * Step4: 对特征向量进行线性分类和识别

# %% [markdown]
# ### 25.简述Fast-RCNN与RCNN相比有什么区别?

# %% [markdown]
# * 先把图进行一次CNN,对每个特征框仅在原图的特征图上进行提取
# * 加入池化(Rol polling),固定输出大小
